# %% [markdown]
# <a href="https://colab.research.google.com/github/patel54/-frankData612/blob/main/Sweta_Patel_Assignment05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment for Week 5
# (Chapter 6 & 7)

# %% [markdown]
# ## Purpose:
# This assignment is intended to help you do the following:
# 1.	Differentiate between categorical and non-categorical variables
# 2.	Convert variables from one type to another
# 3.	Familiarize with strings

# %% [markdown]
# ## Action Items:
# •	Convert data
# 1. Work on your selected data set and covert a column of non-categorical type into a categorical type.
# 2. Convert another column into a string type.
# 3. Post your work on GitHub
# 4. Add a README file

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/frankData612/data_612/master/State_Drug_Utilization_Data_2010/State_Drug_Utilization_Data_2010.csv')

df.head()
# Out:
#    Unnamed: 0 Utilization Type  ...             Location          NDC
# 0      128037             MCOU  ...  (31.1801, -91.8749)  37205013705
# 1      491755             FFSU  ...  (39.3498, -75.5148)  62756076388
# 2     2568076             FFSU  ...  (44.2853, -99.4632)  46987032311
# 3      491263             FFSU  ...  (43.3504, -84.5603)    781518501
# 4      836489             FFSU  ...                  NaN  51552080906
#
# [5 rows x 21 columns]

# %%
print (df.dtypes)
# Out:
# Unnamed: 0                          int64
# Utilization Type                   object
# State                              object
# Labeler Code                        int64
# Product Code                        int64
# Package Size                        int64
# Year                                int64
# Quarter                             int64
# Product Name                       object
# Units Reimbursed                  float64
# Suppression Used                     bool
# Number of Prescriptions             int64
# Total Amount Reimbursed           float64
# Medicaid Amount Reimbursed        float64
# Non Medicaid Amount Reimbursed    float64
# Quarter Begin                      object
# Quarter Begin Date                 object
# Latitude                          float64
# Longitude                         float64
# Location                           object
# NDC                                 int64
# dtype: object

# %%
obj_df = df.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#   Utilization Type State  ... Quarter Begin Date             Location
# 0             MCOU    MA  ...         10/01/2010  (31.1801, -91.8749)
# 1             FFSU    FL  ...         01/01/2010  (39.3498, -75.5148)
# 2             FFSU    UT  ...         04/01/2010  (44.2853, -99.4632)
# 3             FFSU    MN  ...         10/01/2010  (43.3504, -84.5603)
# 4             FFSU    XX  ...         04/01/2010                  NaN
#
# [5 rows x 7 columns]

# %%
df[['State', 'Utilization Type', 'Product Name', 'Total Amount Reimbursed', 'Quarter Begin', 'Quarter Begin Date', 'Location' ]] = df[['State', 'Utilization Type', 'Product Name', 'Total Amount Reimbursed', 'Quarter Begin', 'Quarter Begin Date', 'Location' ]].astype('category')

print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156220 entries, 0 to 156219
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0                      156220 non-null  int64
#  1   Utilization Type                156220 non-null  category
#  2   State                           156220 non-null  category
#  3   Labeler Code                    156220 non-null  int64
#  4   Product Code                    156220 non-null  int64
#  5   Package Size                    156220 non-null  int64
#  6   Year                            156220 non-null  int64
#  7   Quarter                         156220 non-null  int64
#  8   Product Name                    156166 non-null  category
#  9   Units Reimbursed                156220 non-null  float64
#  10  Suppression Used                156220 non-null  bool
#  11  Number of Prescriptions         156220 non-null  int64
# ...

# %%
df['Total Amount Reimbursed'] = df['Total Amount Reimbursed'].astype('str')

print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156220 entries, 0 to 156219
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0                      156220 non-null  int64
#  1   Utilization Type                156220 non-null  category
#  2   State                           156220 non-null  category
#  3   Labeler Code                    156220 non-null  int64
#  4   Product Code                    156220 non-null  int64
#  5   Package Size                    156220 non-null  int64
#  6   Year                            156220 non-null  int64
#  7   Quarter                         156220 non-null  int64
#  8   Product Name                    156166 non-null  category
#  9   Units Reimbursed                156220 non-null  float64
#  10  Suppression Used                156220 non-null  bool
#  11  Number of Prescriptions         156220 non-null  int64
# ...

# %%
print (df.dtypes)
# Out:
# Unnamed: 0                          int64
# Utilization Type                   object
# State                              object
# Labeler Code                        int64
# Product Code                        int64
# Package Size                        int64
# Year                                int64
# Quarter                             int64
# Product Name                       object
# Units Reimbursed                  float64
# Suppression Used                     bool
# Number of Prescriptions             int64
# Total Amount Reimbursed           float64
# Medicaid Amount Reimbursed        float64
# Non Medicaid Amount Reimbursed    float64
# Quarter Begin                      object
# Quarter Begin Date                 object
# Latitude                          float64
# Longitude                         float64
# Location                           object
# NDC                                 int64
# dtype: object

# %%
df['Units Reimbursed'] = df['Units Reimbursed'].astype('str')
print (df.dtypes)
# Out:
# Unnamed: 0                           int64
# Utilization Type                  category
# State                             category
# Labeler Code                         int64
# Product Code                         int64
# Package Size                         int64
# Year                                 int64
# Quarter                              int64
# Product Name                      category
# Units Reimbursed                    object
# Suppression Used                      bool
# Number of Prescriptions              int64
# Total Amount Reimbursed             object
# Medicaid Amount Reimbursed         float64
# Non Medicaid Amount Reimbursed     float64
# Quarter Begin                     category
# Quarter Begin Date                category
# Latitude                           float64
# Longitude                          float64
# Location                          category
# NDC                                  int64
# dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0 Utilization Type  ...             Location          NDC
# 0      128037             MCOU  ...  (31.1801, -91.8749)  37205013705
# 1      491755             FFSU  ...  (39.3498, -75.5148)  62756076388
# 2     2568076             FFSU  ...  (44.2853, -99.4632)  46987032311
# 3      491263             FFSU  ...  (43.3504, -84.5603)    781518501
# 4      836489             FFSU  ...                  NaN  51552080906
#
# [5 rows x 21 columns]
